# %%
import pandas as pd
import numpy as np

from sklearn.datasets import fetch_openml

from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import accuracy_score

import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt

# %%
mnist = fetch_openml('mnist_784')

# %%
mnist.keys()

# %%
# This will take some time to run since its a large dataset
df_mnist = mnist['data']

# %%
# Find out the number of unique brands in the MNIST dataset
mnist['target'].nunique()

# %%
mnist_target = list(mnist['target'])

# %%
df_mnist

# %%
plt.gray() # B/W Images
plt.figure(figsize = (10,9)) # Adjusting figure size
# Displaying a grid of 3x3 images
for i in range(9):
  plt.subplot(3,3,i+1)
  plt.imshow(np.array(df_mnist.loc[i]).reshape(28,28))

# %%
kmeans = MiniBatchKMeans(n_clusters = 10, init='k-means++', max_iter=300, n_init=10, random_state=0)
# Fitting the model to training set
y = kmeans.fit_predict(df_mnist)

df_crosstab = pd.crosstab(pd.Series(mnist_target),pd.Series(y))
