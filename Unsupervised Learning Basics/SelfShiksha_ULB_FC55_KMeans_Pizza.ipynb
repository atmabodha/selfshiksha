# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

import plotly.express as px
import plotly.graph_objs as go

# %%
df = pd.read_csv("SelfShiksha_ULB_FC33_PCA_Pizza.csv")

# %%
df

# %%
# Find out the number of unique brands in the Pizza dataset
df["brand"].nunique()

# %% [markdown]
# # StandardScaler

# %%
df = pd.read_csv("SelfShiksha_ULB_FC33_PCA_Pizza.csv")
X = np.array(df.drop(["brand","id"],axis=1))
X = StandardScaler().fit_transform(X)
kmeans = KMeans(n_clusters=10, init='k-means++', max_iter=300, n_init=10, random_state=0)
y=kmeans.fit_predict(X)
df["cluster_label"] = y
pd.crosstab(df["brand"],df["cluster_label"])

# %%
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

fig = px.line(y=wcss)
fig.update_layout(xaxis_title="Number of Clusters",yaxis_title="WCSS")
fig.show()

# %% [markdown]
# # No Scaling

# %%
df = pd.read_csv("SelfShiksha_ULB_FC33_PCA_Pizza.csv")
X = np.array(df.drop(["brand","id"],axis=1))
kmeans = KMeans(n_clusters=10, init='k-means++', max_iter=300, n_init=10, random_state=0)
y=kmeans.fit_predict(X)
df["cluster_label"] = y
pd.crosstab(df["brand"],df["cluster_label"])

# %%
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

fig = px.line(y=wcss)
fig.update_layout(xaxis_title="Number of Clusters",yaxis_title="WCSS")
fig.show()

# %% [markdown]
# # MinMaxScaler

# %%
df = pd.read_csv("SelfShiksha_ULB_FC33_PCA_Pizza.csv")
X = np.array(df.drop(["brand","id"],axis=1))
X = MinMaxScaler().fit_transform(X)
kmeans = KMeans(n_clusters=10, init='k-means++', max_iter=300, n_init=10, random_state=0)
y=kmeans.fit_predict(X)
df["cluster_label"] = y
pd.crosstab(df["brand"],df["cluster_label"])

# %%
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

fig = px.line(y=wcss)
fig.update_layout(xaxis_title="Number of Clusters",yaxis_title="WCSS")
fig.show()
